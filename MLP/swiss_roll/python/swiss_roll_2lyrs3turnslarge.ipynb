# %% [markdown]
# <a href="https://colab.research.google.com/github/tibaris/EntropicSparsificationNN/blob/main/swiss_roll_2lyrs3turnslarge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage import io, exposure

import numpy as np
import scipy
import scipy.ndimage
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix
from sklearn import metrics
from scipy.ndimage import gaussian_filter

import time
from skimage.color import rgb2gray
from skimage.transform import rescale

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler, MaxAbsScaler
from sklearn import svm

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.optim.lr_scheduler as sched

# %%
def count_parameters(model): return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
import csv
import pandas as pd
import time
import gc
import sys

# %%
train_data = pd.read_csv("/content/swissroll-10000-turn3.csv", header=None)
train_data = train_data.to_numpy()

# %%
train_data.shape
# Out:
# (2, 20000)

# %%
xA = train_data[0,:10000]
yA = train_data[1,:10000]
xB = train_data[0,10000:]
yB = train_data[1,10000:]
plt.scatter(xA,yA)
plt.scatter(xB,yB)

# %%
train_data = np.transpose(train_data)
train_data = torch.from_numpy(train_data)
print(train_data.shape)
# Out:
# torch.Size([20000, 2])

# %%
train_num = train_data.shape[0]
torch.manual_seed(0)
permutation = torch.randperm(train_num)

# %%
train_x = train_data[permutation[:15000],:]
train_y = (permutation[:15000]<train_num/2)*1
train_x = train_x.reshape([train_x.shape[0],train_x.shape[1],1,1])
print(train_x.shape)
print(train_y.shape)
# Out:
# torch.Size([15000, 2, 1, 1])
# torch.Size([15000])

# %%
test_x = train_data[permutation[15000:],:]
test_y = (permutation[15000:]<train_num/2)*1
test_x = test_x.reshape([test_x.shape[0],test_x.shape[1],1,1])
print(test_x.shape)
print(test_y.shape)
# Out:
# torch.Size([5000, 2, 1, 1])
# torch.Size([5000])

# %%
train_y
# Out:
# tensor([0, 0, 1,  ..., 1, 1, 0])

# %%
class SimplePerceptron(nn.Module):

    def __init__(self):
        super(SimplePerceptron, self).__init__()
        self.conv1 = nn.Conv2d(2,400,kernel_size = (1,1))
        self.conv2 = nn.Conv2d(400,400,kernel_size = (1,1))
        self.conv3 = nn.Conv2d(400,400,kernel_size = (1,1))
        self.conv4 = nn.Conv2d(400,400,kernel_size = (1,1))
        self.conv5 = nn.Conv2d(400,1,kernel_size = (1,1))

        self.bn1 = nn.BatchNorm2d(400, affine=False)
        self.bn2 = nn.BatchNorm2d(400, affine=False)
        self.bn3 = nn.BatchNorm2d(400, affine=False)
        self.bn4 = nn.BatchNorm2d(400, affine=False)


    def forward(self, x):

        #1st  layer
        #x = self.bn1(x)
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = F.relu(x)

        x = self.conv3(x)
        x = self.bn3(x)
        x = F.relu(x)

        x = self.conv4(x)
        x = self.bn4(x)
        x = F.relu(x)

        x = self.conv5(x)
        #x = F.softmax(x)
        x = F.sigmoid(x)
        return x

# %%
model = SimplePerceptron().double()
print(count_parameters(model))
# Out:
# 482801

# %%
n_epochs = 20 # or whatever
batch_size = 50 # or whatever
train_num = 10000

optimizer = optim.Adam(model.parameters(), lr = 0.001)
scheduler = sched.StepLR(optimizer, step_size=4, gamma=0.5)

input = train_x[:10000].double()
target = train_y[:10000].double()

input_v = train_x[10000:].double()
target_v = train_y[10000:].double()

criterion_val = nn.BCELoss()
#criterion_val = loss = nn.CrossEntropyLoss()

for epoch in range(n_epochs):

    # X is a torch Variable
    permutation = torch.randperm(train_num)
    if(epoch % 2 == 1):
        print("Epoch:")
        print(epoch)
        print("Train loss:")
        print(t_loss/train_num*batch_size)
        print("val:")
        val_loss=0
        model.eval()
        v1 = model(input_v)
        #for i in range(200):
            #v1 = model(input_v[(i*50):((i+1)*50)])
            #v2  = target_v[(i*50):((i+1)*50)]
            #v1 = torch.argmax(v1, dim=1)
            #print(v1.shape)
        val_loss = criterion_val(v1[:,0,0,0],target_v)
        #gc.collect()
        #val_loss = val_loss + criterion_val(v1[:,:,0,0],v2)
        #print(criterion_val(model.forward(val_x2), val_y2))
        print("Validation loss:")
        print(val_loss)
        print("--------")
        model.train()
    t_loss = 0
    gc.collect()

    for i in range(0,train_num, batch_size):
        optimizer.zero_grad()
        indices = permutation[i:(i+batch_size)]
        batch_x = input[indices]
        batch_y = target[indices]
        #batch_w = input_w[indices]
        #criterion3 = nn.BCELoss(weight=batch_w)
        #print(batch_x.shape)
        outputs = model.forward(batch_x)
        #print(outputs[:,:,0,0].shape)
        #print(torch.max(outputs[:,:,0,0]))
        #print(torch.max(batch_y))
        #print(torch.min(batch_y))
        #print(batch_y.shape)
        #loss = criterion3(outputs,batch_y)
        loss = criterion_val(outputs[:,0,0,0],batch_y)
        #print(loss)

        if(epoch % 2 == 0):
            t_loss += loss

        loss.backward()
        optimizer.step()
        gc.collect()

    scheduler.step()
    gc.collect()
# Out:
# Epoch:
# 1
# Train loss:
# tensor(0.6558, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.5650, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 3
# Train loss:
# tensor(0.6317, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.5134, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 5
# Train loss:
# tensor(0.5861, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.4068, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 7
# Train loss:
# tensor(0.5583, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.3326, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 9
# Train loss:
# tensor(0.5401, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2955, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 11
# Train loss:
# tensor(0.5293, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2816, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 13
# Train loss:
# tensor(0.5396, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2629, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 15
# Train loss:
# tensor(0.4982, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2250, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 17
# Train loss:
# tensor(0.5017, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2274, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 19
# Train loss:
# tensor(0.5175, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2428, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------

# %%
for epoch in range(n_epochs):

    # X is a torch Variable
    permutation = torch.randperm(train_num)
    if(epoch % 2 == 1):
        print("Epoch:")
        print(epoch)
        print("Train loss:")
        print(t_loss/train_num*batch_size)
        print("val:")
        val_loss=0
        model.eval()
        v1 = model(input_v)
        #for i in range(200):
            #v1 = model(input_v[(i*50):((i+1)*50)])
            #v2  = target_v[(i*50):((i+1)*50)]
            #v1 = torch.argmax(v1, dim=1)
            #print(v1.shape)
        val_loss = criterion_val(v1[:,0,0,0],target_v)
        #gc.collect()
        #val_loss = val_loss + criterion_val(v1[:,:,0,0],v2)
        #print(criterion_val(model.forward(val_x2), val_y2))
        print("Validation loss:")
        print(val_loss)
        print("--------")
        model.train()
    t_loss = 0
    gc.collect()

    for i in range(0,train_num, batch_size):
        optimizer.zero_grad()
        indices = permutation[i:(i+batch_size)]
        batch_x = input[indices]
        batch_y = target[indices]
        #batch_w = input_w[indices]
        #criterion3 = nn.BCELoss(weight=batch_w)
        #print(batch_x.shape)
        outputs = model.forward(batch_x)
        #print(outputs[:,:,0,0].shape)
        #print(torch.max(outputs[:,:,0,0]))
        #print(torch.max(batch_y))
        #print(torch.min(batch_y))
        #print(batch_y.shape)
        #loss = criterion3(outputs,batch_y)
        loss = criterion_val(outputs[:,0,0,0],batch_y)
        #print(loss)

        if(epoch % 2 == 0):
            t_loss += loss

        loss.backward()
        optimizer.step()
        gc.collect()

    scheduler.step()
    gc.collect()
# Out:
# Epoch:
# 1
# Train loss:
# tensor(0.4722, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2093, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 3
# Train loss:
# tensor(0.4662, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2234, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 5
# Train loss:
# tensor(0.4674, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2254, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 7
# Train loss:
# tensor(0.4859, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2077, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 9
# Train loss:
# tensor(0.4993, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.1995, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 11
# Train loss:
# tensor(0.5080, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2026, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 13
# Train loss:
# tensor(0.5175, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2061, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 15
# Train loss:
# tensor(0.4742, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2217, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 17
# Train loss:
# tensor(0.5061, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2096, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------
# Epoch:
# 19
# Train loss:
# tensor(0.5052, dtype=torch.float64, grad_fn=<MulBackward0>)
# val:
# Validation loss:
# tensor(0.2143, dtype=torch.float64, grad_fn=<BinaryCrossEntropyBackward0>)
# --------

# %%
def accuracy(y1,y2):
    train_acc = torch.sum(y1 == y2)
    print(train_acc)
    final_train_acc = train_acc/y2.shape[0]
    return final_train_acc

# %%
#train
v = model(input)
v[v>=0.5] = 1
v[v<0.5] = 0
#val
v1 = model(input_v)
v1[v1>=0.5] = 1
v1[v1<0.5] = 0
#test
v2 = model(test_x)
v2[v2>=0.5] = 1
v2[v2<0.5] = 0

# %%
print(accuracy(v[:,0,0,0],target))
print(accuracy(v1[:,0,0,0],target_v))
print(accuracy(v2[:,0,0,0],test_y))
# Out:
# tensor(9918)
# tensor(0.9918)
# tensor(4951)
# tensor(0.9902)
# tensor(4936)
# tensor(0.9872)

# %%
print(accuracy(v[:,0,0,0],target))
print(accuracy(v1[:,0,0,0],target_v))
print(accuracy(v2[:,0,0,0],test_y))
# Out:
# tensor(9881)
# tensor(0.9881)
# tensor(4930)
# tensor(0.9860)
# tensor(4913)
# tensor(0.9826)

# %%
test_x.shape
# Out:
# torch.Size([5000, 2, 1, 1])

# %%
xA = test_x[v2[:,0,0,0]==1,0,0,0]
yA = test_x[v2[:,0,0,0]==1,1,0,0]
xB = test_x[v2[:,0,0,0]==0,0,0,0]
yB = test_x[v2[:,0,0,0]==0,1,0,0]
plt.scatter(xA,yA)
plt.scatter(xB,yB)

# %% [markdown]
# Visualization

# %%
print(torch.min(test_x[:,0,0,0]))
print(torch.max(test_x[:,0,0,0]))
print(torch.min(test_x[:,1,0,0]))
print(torch.max(test_x[:,1,0,0]))
# Out:
# tensor(-0.9681, dtype=torch.float64)
# tensor(1.1331, dtype=torch.float64)
# tensor(-1.0513, dtype=torch.float64)
# tensor(0.8849, dtype=torch.float64)

# %%
Lx = -1.5
Rx = 1.5
Ly = -1.5
Ry = 1.5

# %%
#grid
x1 = np.array([0])
x2 = np.array([0])
for i in range(100):
  for j in range(100):
    x1 = np.concatenate([x1,[-2+4/100*i]])
    x2 = np.concatenate([x2,[-2+4/100*j]])

# %%
x1.shape
torch.from_numpy(x1).shape
# Out:
# torch.Size([10001])

# %%
grid = torch.zeros([pow(10,4)+1,2,1,1])
print(grid.shape)
grid[:,0,0,0] = torch.from_numpy(x1)
grid[:,1,0,0] = torch.from_numpy(x2)
# Out:
# torch.Size([10001, 2, 1, 1])

# %%
v = model(grid.double())
print(v.shape)
v1 = v[1:].reshape([100,100])
plt.imshow(v1.detach().numpy())
# Out:
# torch.Size([10001, 1, 1, 1])

# %%
v = model(grid.double())
v[v>=0.5] = 1
v[v<0.5] = 0

# %%
#torch.save(model.state_dict(), "/content/FCC-swiss-roll-3turn-10k-large.pth")

# %%
xA = grid[v[:,0,0,0]==1,0,0,0]
yA = grid[v[:,0,0,0]==1,1,0,0]
xB = grid[v[:,0,0,0]==0,0,0,0]
yB = grid[v[:,0,0,0]==0,1,0,0]
plt.scatter(xA,yA)
plt.scatter(xB,yB)
